# %%
import os
import pandas as pd
import numpy as np
import anndata as ann

import spatialdm as sdm
from spatialdm.datasets import dataset
import spatialdm.plottings as pl

import matplotlib.pyplot as plt
print("SpatailDM version: %s" %sdm.__version__)

import scanpy as sc
# Out:
# SpatailDM version: 0.3.1

# %%
# Paths
h5ad_dir = "/dcs04/lieber/marmaypag/spatialNac_LIBD4125/spatial_NAc/processed-data/22_gene_risk_LR_analysis/03_tensor_cell2cell/input_files"
sample="Br6522"
h5ad_path = os.path.join(h5ad_dir, f"{sample}.h5ad")
adata = sc.read_h5ad(h5ad_path)
sc.pl.spatial(adata, color=['precast_clusters'], size=1.3, palette='Set1')
# Out:
# /tmp/ipykernel_1973494/2019636611.py:6: FutureWarning: Use `squidpy.pl.spatial_scatter` instead.
#   sc.pl.spatial(adata, color=['precast_clusters'], size=1.3, palette='Set1')

# %%
sdm.weight_matrix(adata, l=75, cutoff=0.2, single_cell=False)

# %%
adata.obsp['weight'].toarray()
# Out:
# array([[0.8767722, 0.       , 0.       , ..., 0.       , 0.       ,
#         0.       ],
#        [0.       , 0.8767722, 0.       , ..., 0.       , 0.       ,
#         0.       ],
#        [0.       , 0.       , 0.8767722, ..., 0.       , 0.       ,
#         0.       ],
#        ...,
#        [0.       , 0.       , 0.       , ..., 0.8767722, 0.       ,
#         0.       ],
#        [0.       , 0.       , 0.       , ..., 0.       , 0.8767722,
#         0.       ],
#        [0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#         0.8767722]], shape=(19206, 19206))
