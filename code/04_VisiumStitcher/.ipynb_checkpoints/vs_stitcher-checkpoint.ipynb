# %%
import scanpy as sc
import visium_stitcher as vs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read in the .csv with sample key
homeDir = "/data/abattle4/prashanthi/spatial_NAc/"
sample_key = pd.read_csv(homeDir + "raw-data/sample_key_spatial_NAc.csv")
# Out:
#            Slide   Brain   Age  Sex Diagnosis Image J  In analysis  \
# 0  V12D07-074_A1  Br2720  48.22   F   Control      Yes         Yes
# 1  V12D07-074_B1  Br2720  48.22   F   Control      Yes         Yes
# 2  V12D07-074_C1  Br2720  48.22   F   Control      Yes         Yes
# 3  V12D07-074_D1  Br2720  48.22   F   Control      Yes         Yes
# 4  V11U23-406-C1  Br8667  37.33   F   Control      Yes         Yes
# 5  V11U23-406-D1  Br8667  37.33   F   Control      Yes         Yes
#
#                                        XML file name  \
# 0  processed-data/02_image_stitching/ImageJ_out/t...
# 1  processed-data/02_image_stitching/ImageJ_out/t...
# 2  processed-data/02_image_stitching/ImageJ_out/t...
# 3  processed-data/02_image_stitching/ImageJ_out/t...
# 4  processed-data/02_image_stitching/ImageJ_out/t...
# 5  processed-data/02_image_stitching/ImageJ_out/t...
#
#                                  Stitched image file
# 0  processed-data/02_image_stitching/ImageJ_out/s...
# 1  processed-data/02_image_stitching/ImageJ_out/s...
# 2  processed-data/02_image_stitching/ImageJ_out/s...
# 3  processed-data/02_image_stitching/ImageJ_out/s...
# 4  processed-data/02_image_stitching/ImageJ_out/s...
# 5  processed-data/02_image_stitching/ImageJ_out/s...

# %% [raw]
# adata = sc.read_visium(homeDir + "processed-data/01_spaceranger_reorg/" +
#                        sample_key.Slide[0] + "/outs", count_file="filtered_feature_bc_matrix.h5")
# adata.var_names_make_unique()
# adata.obs_names = [sample_key.Slide[0]+i for i in adata1.obs_names]
# adata.obs['sample'] = sample_key.Slide[0]
# transform = vs.transform_finder(homeDir + sample_key['XML file name'][0])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 transform
#
# NameError: name 'transform' is not defined
